# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td width="15%">
#             <img src="homework.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b> Take-Home <br>(Day 4)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### About the dataset (Life Expectancy Data)
#
# The dataset contains the health data of 2938 individuals useful for predicting the life expentency of the individuals. The features are related to economical factors, immunity realted factors, social factors and so on.
#
# Attribute Information:
#
# **Country:** Country of the recorded data
#
# **Year:** Year of the recorded data
#
# **Status:** Status of the country
#
# **Life expectancy:** Life expectancy in age (target/dependent variable)
#
# **Adult mortality:** Rate of adult mortality
#
# **Infant deaths:** Number of Infant Deaths per 1000 population
#
# **Alcohol:** Alcohol consumption (in litres of pure alcohol)
#
# **Percentage expenditure:** Expenditure on health as a percentage of GDP
#
# **Hepatitis B:** Hepatitis B immunization coverage among 1-year-olds (%)
#
# **Measles:** Number of reported cases per 1000 population
#
# **BMI:** Average BMI of entire population
#
# **Under-five deaths:** Number of under-five deaths per 1000 population
#
# **Polio:** Polio immunization coverage among 1-year-olds (%)
#
# **Total expenditure:** Government expenditure on health as a percentage of total government expenditure (%)
#
# **Diphtheria:** DTP3 immunization coverage among 1-year-olds (%)
#
# **HIV/AIDS:** Deaths per 1000 live births HIV/AIDS (0-4 years)
#
# **GDP:** Gross Domestic Product per capita (in USD)
#
# **Population:** Population of the country
#
# **Thinness 1-19 years:** Prevalence of thinness for age 1 to 19 (%)
#
# **Thinness 5-9 years:** Prevalence of thinness for age 5 to 9 (%)
#
# **Income composition of resources:** Human Development Index in terms of income composition of resources
#
# **Schooling:** Number of years of Schooling

# %% [markdown]
# **Import the required libraries**

# %%
import numpy as np
import pandas as pd
from pandas import Series as sr
from pandas import DataFrame as df
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Load the life expectancy dataset and print the first five observations

# %%
df1=pd.read_csv('Life Expectancy Data.csv')
df1.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
# 3             69     0.01               78.184215         67.0     2787  ...
# 4             71     0.01                7.097109         68.0     3013  ...
#
#    Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# 0    6.0               8.16        65.0       0.1  584.259210    33736494
# 1   58.0               8.18        62.0       0.1  612.696514      327582
# 2   62.0               8.13        64.0       0.1  631.744976    31731688
# 3   67.0               8.52        67.0       0.1  669.959000     3696958
# 4   68.0               7.87        68.0       0.1   63.537231     2978599
#
#    Thinness  1-19 years Thinness 5-9 years  Income composition of resources  \
# 0                  17.2               17.3                            0.479
# 1                  17.5               17.5                            0.476
# 2                  17.7               17.7                            0.470
# 3                  17.9               18.0                            0.463
# 4                  18.2               18.2                            0.454
#
#    Schooling
# 0       10.1
# 1       10.0
# 2        9.9
# 3        9.8
# 4        9.5
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Check the data type of each variable and if any variable is wrongly identified, do the needful</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df1.dtypes
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult mortality                    float64
# Infant deaths                        int64
# Alcohol                            float64
# Percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
# BMI                                float64
# Under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
# HIV/AIDS                           float64
# GDP                                float64
# Population                         float64
# Thinness  1-19 years               float64
# Thinness 5-9 years                 float64
# Income composition of resources    float64
# Schooling                          float64
# dtype: object

# %%
df1["Population"]=pd.to_numeric(df1['Population'], errors='coerce')

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Create a DataFrame containing the count and percentage of missing entries in each variable</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df1.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
# 3             69     0.01               78.184215         67.0     2787  ...
# 4             71     0.01                7.097109         68.0     3013  ...
#
#    Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# 0    6.0               8.16        65.0       0.1  584.259210    33736494
# 1   58.0               8.18        62.0       0.1  612.696514      327582
# 2   62.0               8.13        64.0       0.1  631.744976    31731688
# 3   67.0               8.52        67.0       0.1  669.959000     3696958
# 4   68.0               7.87        68.0       0.1   63.537231     2978599
#
#    Thinness  1-19 years Thinness 5-9 years  Income composition of resources  \
# 0                  17.2               17.3                            0.479
# 1                  17.5               17.5                            0.476
# 2                  17.7               17.7                            0.470
# 3                  17.9               18.0                            0.463
# 4                  18.2               18.2                            0.454
#
#    Schooling
# 0       10.1
# 1       10.0
# 2        9.9
# 3        9.8
# 4        9.5
#
# [5 rows x 22 columns]

# %%
df2=df({'count':df1.isnull().sum()})

# %%
df2['percentage']=(df1.isnull().sum()/df1.shape[0]*100)
print(df2.head())
print(df2.tail())
# Out:
#                  count  percentage
# Country              0    0.000000
# Year                 0    0.000000
# Status              16    0.544588
# Life expectancy     10    0.340368
# Adult mortality     10    0.340368
#                                  count  percentage
# Population                           0    0.000000
# Thinness  1-19 years                34    1.157250
# Thinness 5-9 years                  34    1.157250
# Income composition of resources    167    5.684139
# Schooling                          163    5.547992

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3a. Are there any extreme values present in the government's total expenditure on health?
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df1.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy', 'Adult mortality',
#        'Infant deaths', 'Alcohol', 'Percentage expenditure', 'Hepatitis B',
#        'Measles', 'BMI', 'Under-five deaths', 'Polio', 'Total expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'Thinness  1-19 years',
#        'Thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
sns.boxplot(x=df1['Total expenditure'])
plt.show()

# %% [raw]
# yes there are extreme values/outliers present in government's total expenditure

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3b. Remove the outliers present in 'Total expenditure' using the quartiles of the variable
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
q1=df1['Total expenditure'].quantile(0.25)
q1
# Out:
# 4.26

# %%
q3=df1['Total expenditure'].quantile(0.75)
q3
# Out:
# 7.4925

# %%
iqr=q3-q1
iqr
# Out:
# 3.2325

# %%
u_l=q3+(1.5*iqr)
u_l
# Out:
# 12.341249999999999

# %%
l_l=q1-(1.5*iqr)
l_l
# Out:
# -0.5887500000000001

# %%
outlier_removal=df1[(df1['Total expenditure']>l_l) & (df1['Total expenditure']<u_l)]
outlier_removal
# Out:
#           Country  Year      Status  Life expectancy  Adult mortality  \
# 0     Afghanistan  2015  Developing             65.0            263.0
# 1     Afghanistan  2014  Developing             59.9            271.0
# 2     Afghanistan  2013  Developing             59.9            268.0
# 3     Afghanistan  2012  Developing             59.5            272.0
# 4     Afghanistan  2011  Developing             59.2            275.0
# ...           ...   ...         ...              ...              ...
# 2933     Zimbabwe  2004  Developing             44.3            723.0
# 2934     Zimbabwe  2003  Developing             44.5            715.0
# 2935     Zimbabwe  2002  Developing             44.8             73.0
# 2936     Zimbabwe  2001  Developing             45.3            686.0
# 2937     Zimbabwe  2000  Developing             46.0            665.0
#
#       Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  \
# 0                62     0.01               71.279624         65.0     1154
# 1                64     0.01               73.523582         62.0      492
# 2                66     0.01               73.219243         64.0      430
# 3                69     0.01               78.184215         67.0     2787
# 4                71     0.01                7.097109         68.0     3013
# ...             ...      ...                     ...          ...      ...
# 2933             27     4.36                0.000000         68.0       31
# 2934             26     4.06                0.000000          7.0      998
# 2935             25     4.43                0.000000         73.0      304
# 2936             25     1.72                0.000000         76.0      529
# 2937             24     1.68                0.000000         79.0     1483
#
#       ...  Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  \
# 0     ...    6.0               8.16        65.0       0.1  584.259210
# 1     ...   58.0               8.18        62.0       0.1  612.696514
# 2     ...   62.0               8.13        64.0       0.1  631.744976
# 3     ...   67.0               8.52        67.0       0.1  669.959000
# 4     ...   68.0               7.87        68.0       0.1   63.537231
# ...   ...    ...                ...         ...       ...         ...
# 2933  ...   67.0               7.13        65.0      33.6  454.366654
# 2934  ...    7.0               6.52        68.0      36.7  453.351155
# 2935  ...   73.0               6.53        71.0      39.8   57.348340
# 2936  ...   76.0               6.16        75.0      42.1  548.587312
# 2937  ...   78.0               7.10        78.0      43.5  547.358879
#
#       Population  Thinness  1-19 years Thinness 5-9 years  \
# 0       33736494                  17.2               17.3
# 1         327582                  17.5               17.5
# 2       31731688                  17.7               17.7
# 3        3696958                  17.9               18.0
# 4        2978599                  18.2               18.2
# ...          ...                   ...                ...
# 2933    12777511                   9.4                9.4
# 2934    12633897                   9.8                9.9
# 2935      125525                   1.2                1.3
# 2936    12366165                   1.6                1.7
# 2937    12222251                  11.0               11.2
#
#       Income composition of resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [2680 rows x 22 columns]

# %%
df1.shape
# Out:
# (2938, 22)

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4. Split the data such that 'X' will contain all the indepentdent variables and 'y' will contain the target variable</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Hint:** 'Life expectancy' is the target variable depending on the remaining variables.

# %%
from sklearn.model_selection import train_test_split

# %%
x=df1.drop('Life expectancy',inplace=False,axis=1)
x.head()
# Out:
#        Country  Year      Status  Adult mortality  Infant deaths  Alcohol  \
# 0  Afghanistan  2015  Developing            263.0             62     0.01
# 1  Afghanistan  2014  Developing            271.0             64     0.01
# 2  Afghanistan  2013  Developing            268.0             66     0.01
# 3  Afghanistan  2012  Developing            272.0             69     0.01
# 4  Afghanistan  2011  Developing            275.0             71     0.01
#
#    Percentage expenditure  Hepatitis B  Measles   BMI  ...  Polio  \
# 0               71.279624         65.0     1154  19.1  ...    6.0
# 1               73.523582         62.0      492  18.6  ...   58.0
# 2               73.219243         64.0      430  18.1  ...   62.0
# 3               78.184215         67.0     2787  17.6  ...   67.0
# 4                7.097109         68.0     3013  17.2  ...   68.0
#
#    Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# 0               8.16        65.0       0.1  584.259210    33736494
# 1               8.18        62.0       0.1  612.696514      327582
# 2               8.13        64.0       0.1  631.744976    31731688
# 3               8.52        67.0       0.1  669.959000     3696958
# 4               7.87        68.0       0.1   63.537231     2978599
#
#   Thinness  1-19 years  Thinness 5-9 years  Income composition of resources  \
# 0                 17.2                17.3                            0.479
# 1                 17.5                17.5                            0.476
# 2                 17.7                17.7                            0.470
# 3                 17.9                18.0                            0.463
# 4                 18.2                18.2                            0.454
#
#    Schooling
# 0       10.1
# 1       10.0
# 2        9.9
# 3        9.8
# 4        9.5
#
# [5 rows x 21 columns]

# %%
y=df1['Life expectancy']
y.head()
# Out:
# 0    65.0
# 1    59.9
# 2    59.9
# 3    59.5
# 4    59.2
# Name: Life expectancy, dtype: float64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. Split the independent variables into two sets with the proportion of 70:30</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=0)

# %%
x_train.shape
# Out:
# (2056, 21)

# %%
x_test.shape
# Out:
# (882, 21)

# %%
y_train.shape
# Out:
# (2056,)

# %%
y_test.shape
# Out:
# (882,)

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. How would you treat the missing values in the variable 'GDP'?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df1['GDP'].isnull().value_counts()
# Out:
# False    2490
# True      448
# Name: GDP, dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.kdeplot(df1['GDP'])
plt.axvline(df1['GDP'].mean(),color='r',label='mean')
plt.axvline(df1['GDP'].median(),color='g',label='median')
plt.show()

# %%
a=df1['GDP'].median()
a
# Out:
# 1766.947595

# %%
df1['GDP'].fillna(a)
# Out:
# 0       584.259210
# 1       612.696514
# 2       631.744976
# 3       669.959000
# 4        63.537231
#            ...
# 2933    454.366654
# 2934    453.351155
# 2935     57.348340
# 2936    548.587312
# 2937    547.358879
# Name: GDP, Length: 2938, dtype: float64

# %% [raw]
# we will use median here to fill the null values because mean is easily effected by the outliers and median doesnot effect
# much due to outliers compared to mean

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7.There are 16 observations for which the status of the corresponding country is unknown, impute this status with an appropriate values</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df1.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy', 'Adult mortality',
#        'Infant deaths', 'Alcohol', 'Percentage expenditure', 'Hepatitis B',
#        'Measles', 'BMI', 'Under-five deaths', 'Polio', 'Total expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'Thinness  1-19 years',
#        'Thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
df1['Status'].isnull().value_counts()
# Out:
# False    2922
# True       16
# Name: Status, dtype: int64

# %%
df1[df1['Status'].isnull()]
# Out:
#                   Country  Year Status  Life expectancy  Adult mortality  \
# 6             Afghanistan  2009    NaN             58.6            281.0
# 15            Afghanistan  2000    NaN             54.8            321.0
# 27                Albania  2004    NaN             73.0             17.0
# 46                Algeria  2001    NaN             71.4            145.0
# 65    Antigua and Barbuda  2014    NaN             76.2            131.0
# 75    Antigua and Barbuda  2004    NaN             74.4            149.0
# 82              Argentina  2013    NaN             76.0            119.0
# 93              Argentina  2002    NaN             74.1            138.0
# 104               Armenia  2007    NaN             73.5            132.0
# 118             Australia  2009    NaN             81.7             66.0
# 136               Austria  2007    NaN             81.0              8.0
# 148            Azerbaijan  2011    NaN             71.6            125.0
# 458            Cabo Verde  2005    NaN             71.8            134.0
# 1129                Haiti  2008    NaN             62.1            259.0
# 2003             Paraguay  2003    NaN             71.7            166.0
# 2068             Portugal  2002    NaN             77.2             17.0
#
#       Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  \
# 6                77     0.01               56.762217         63.0     2861
# 15               88     0.01               10.424960         62.0     6532
# 27                1     4.54              221.842800         99.0        7
# 46               20     0.23              147.986071          NaN     2686
# 65                0     8.56             2422.999774         99.0        0
# 75                0     7.28               22.862952         97.0        0
# 82                8     8.28             1001.796332         94.0        0
# 93               12     7.81              470.186914         66.0        0
# 104               1     3.99               44.572200         85.0        1
# 118               1    10.62             7172.275229         94.0      104
# 136               0    12.50             7453.864400         85.0       20
# 148               5     1.98              263.142699         84.0        0
# 458               0     4.26                3.349817         93.0        0
# 1129             16     5.95               63.831957          NaN        0
# 2003              4     6.64              155.423308         86.0        0
# 2068              1    12.00             1904.002310         82.0        8
#
#       ...  Polio  Total expenditure  Diphtheria  HIV/AIDS           GDP  \
# 6     ...   63.0               9.42        63.0       0.1    445.893298
# 15    ...   24.0               8.20        24.0       0.1    114.560000
# 27    ...   98.0               6.38        97.0       0.1   2416.588235
# 46    ...   89.0               3.84        89.0       0.1   1732.857979
# 65    ...   96.0               5.54        99.0       0.2  12888.296670
# 75    ...   97.0               4.21        97.0       0.1   1352.837400
# 82    ...   99.0               4.99        94.0       0.1  12976.636420
# 93    ...   94.0               8.31        93.0       0.1   2579.193168
# 104   ...    9.0               4.31        88.0       0.1   3138.887300
# 118   ...   92.0               9.50        92.0       0.1  42742.998980
# 136   ...   85.0               1.40        85.0       0.1  46586.652500
# 148   ...   91.0               5.10        87.0       0.1   7189.691229
# 458   ...   95.0               4.86        95.0       0.8    248.134590
# 1129  ...   64.0               5.92        63.0       2.4    674.756415
# 2003  ...   86.0               5.99        86.0       0.1   1174.779347
# 2068  ...   96.0               9.15        98.0       0.1  12882.288970
#
#       Population  Thinness  1-19 years Thinness 5-9 years  \
# 6         284331                  18.6               18.7
# 15        293756                   2.3                2.5
# 27        326939                   1.8                1.9
# 46      31592153                   6.4                6.3
# 65             #                   3.3                3.3
# 75             #                   3.5                3.4
# 82      42539925                   1.0                0.9
# 93       3788937                   1.2                1.0
# 104       293356                   2.0                2.1
# 118       216917                   0.7                0.6
# 136      8295487                   1.7                1.9
# 148       917382                   2.8                2.9
# 458       474567                   8.5                8.5
# 1129       97529                   4.2                4.2
# 2003       56795                   2.4                2.3
# 2068     1419631                   0.8                0.6
#
#       Income composition of resources  Schooling
# 6                               0.434        8.9
# 15                              0.338        5.5
# 27                              0.681       10.9
# 46                              0.644       10.9
# 65                              0.782       13.9
# 75                              0.000        0.0
# 82                              0.823       17.3
# 93                              0.776       16.3
# 104                             0.707       11.7
# 118                             0.925       19.1
# 136                             0.860       15.2
# 148                             0.741       11.7
# 458                             0.582       11.2
# 1129                            0.462        8.4
# 2003                            0.642       12.7
# 2068                            0.788       15.9
#
# [16 rows x 22 columns]

# %%
df1['Status'].fillna(method='ffill')
# Out:
# 0       Developing
# 1       Developing
# 2       Developing
# 3       Developing
# 4       Developing
#            ...
# 2933    Developing
# 2934    Developing
# 2935    Developing
# 2936    Developing
# 2937    Developing
# Name: Status, Length: 2938, dtype: object

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. Define a function to find the extreme values in alcohol consumption
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
def extreme(my_data):
    eq1=my_data.quantile(0.25)
    eq3=my_data.quantile(0.75)
    eiqr=eq3-eq1
    low_limit=eq1-(1.5*iqr)
    upper_limit=eq3+(1.5*iqr)
    output=my_data[(my_data<low_limit) | (my_data>upper_limit)]
    return output

# %%
extreme(df1['Alcohol'])
# Out:
# 143     13.20
# 225     13.94
# 226     14.66
# 227     16.35
# 228     17.31
#         ...
# 2065    13.33
# 2066    13.45
# 2067    14.21
# 2176    12.68
# 2177    13.45
# Name: Alcohol, Length: 79, dtype: float64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9. Create a column 'Life_expectancy_level' such that it will contain three levels (High, Medium, Low) based on the life expectancy </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df1['Life expectancy'].describe()
# Out:
# count    2928.000000
# mean       69.224932
# std         9.523867
# min        36.300000
# 25%        63.100000
# 50%        72.100000
# 75%        75.700000
# max        89.000000
# Name: Life expectancy, dtype: float64

# %%
df1['life_expectancy_level']=pd.cut(x=df1['Life expectancy'],bins=[35,54,72,90],labels=['Low','Medium','High'])
df1.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
# 3             69     0.01               78.184215         67.0     2787  ...
# 4             71     0.01                7.097109         68.0     3013  ...
#
#    Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# 0               8.16        65.0       0.1  584.259210    33736494
# 1               8.18        62.0       0.1  612.696514      327582
# 2               8.13        64.0       0.1  631.744976    31731688
# 3               8.52        67.0       0.1  669.959000     3696958
# 4               7.87        68.0       0.1   63.537231     2978599
#
#    Thinness  1-19 years  Thinness 5-9 years Income composition of resources  \
# 0                  17.2                17.3                           0.479
# 1                  17.5                17.5                           0.476
# 2                  17.7                17.7                           0.470
# 3                  17.9                18.0                           0.463
# 4                  18.2                18.2                           0.454
#
#    Schooling  life_expectancy_level
# 0       10.1                 Medium
# 1       10.0                 Medium
# 2        9.9                 Medium
# 3        9.8                 Medium
# 4        9.5                 Medium
#
# [5 rows x 23 columns]

# %%
df1['life_expectancy_level'].isnull().value_counts()
# Out:
# False    2928
# True       10
# Name: life_expectancy_level, dtype: int64

# %%
df1['Life expectancy'].isnull().value_counts()
# Out:
# False    2928
# True       10
# Name: Life expectancy, dtype: int64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Check how life expectancy has changed over the years in China</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
ch=df1[df1['Country']=='China']
ch.groupby('Year').sum()['Life expectancy'].plot(kind='bar')
plt.show()

# %% [raw]
# we observed that over the years in china the life expectancy rate haven't changed much
